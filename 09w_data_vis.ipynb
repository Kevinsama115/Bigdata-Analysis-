# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevinsama115/Bigdata-Analysis-/blob/main/09w_data_vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# %config InlineBackend.figure_format = 'retina'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 28.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (5,3)

# %%
plt.rcParams['figure.figsize']
# Out:
# [5.0, 3.0]

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 46.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=dc2da57dde6ecbd96f7528f4e31bb446773169a3c3115dd3d9878a71d89dd7b4
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# ...

# %%
from pydataset import data
df=data('ToothGrowth')
df.head()
# Out:
#     len supp  dose
# 1   4.2   VC   0.5
# 2  11.5   VC   0.5
# 3   7.3   VC   0.5
# 4   5.8   VC   0.5
# 5   6.4   VC   0.5

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=df ,x= 'dose',y= 'len',hue='supp')
plt.title("dadsa")
plt.xlabel('fdfd')
plt.ylabel('fdfd')
plt.legend (title='supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
##sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp')
sns.boxplot(data=df ,x= 'dose',y= 'len',hue='supp')
sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp',dodge=True,alpha=0.6)
plt.title("dadsa")
plt.title("dadsa")
plt.xlabel('mm')
plt.ylabel('mgday')
plt.legend (title='supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
##sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp')
sns.boxplot(data=df ,x= 'dose',y= 'len',hue='supp')
sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp',dodge=True,alpha=0.6)
plt.title("dadsa")
plt.title("dadsa")
plt.xlabel('mm')
plt.ylabel('mgday')
plt.legend (title='supplement',loc = 'right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
##sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp')
sns.boxplot(data=df ,x= 'dose',y= 'len',hue='supp')
sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp',dodge=True,alpha=0.6)
plt.title("dadsa")
plt.title("dadsa")
plt.xlabel('mm')
plt.ylabel('mgday')
plt.legend (title='supplement', loc= 'center right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
##sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp')
sns.boxplot(data=df ,x= 'dose',y= 'len',hue='supp')
sns.stripplot (data=df ,x= 'dose',y= 'len',hue='supp',dodge=True,alpha=0.6)
plt.title("dadsa")
plt.title("dadsa")
plt.xlabel('mm')
plt.ylabel('mgday')
plt.legend (title='supplement', loc = 'lower center')
plt.tight_layout()
plt.show()

# %%
from pydataset import data
lcs =data('LifeCycleSavings')
lcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Australia to Malaysia
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sr      50 non-null     float64
#  1   pop15   50 non-null     float64
#  2   pop75   50 non-null     float64
#  3   dpi     50 non-null     float64
#  4   ddpi    50 non-null     float64
# dtypes: float64(5)
# memory usage: 2.3+ KB

# %%
lcs.head(
)
# Out:
#               sr  pop15  pop75      dpi  ddpi
# Australia  11.43  29.35   2.87  2329.68  2.87
# Austria    12.07  23.32   4.41  1507.99  3.93
# Belgium    13.17  23.80   4.43  2108.47  3.82
# Bolivia     5.75  41.89   1.67   189.13  0.22
# Brazil     12.88  42.19   0.83   728.47  4.56

# %%
lcs.tail()
# Out:
#              sr  pop15  pop75     dpi   ddpi
# Zambia    18.56  45.25   0.56  138.33   5.14
# Jamaica    7.72  41.12   1.73  380.47  10.23
# Uruguay    9.24  28.13   2.72  766.54   1.88
# Libya      8.89  43.69   2.07  123.58  16.71
# Malaysia   4.71  47.20   0.66  242.69   5.08

# %%
df = lcs[:5][['pop15']]
df
# Out:
#            pop15
# Australia  29.35
# Austria    23.32
# Belgium    23.80
# Bolivia    41.89
# Brazil     42.19

# %%
plt.bar(df.index,df.pop15)
plt.title("older than 15year old")
plt.xlabel('country')
plt.ylabel('older than 15year old % ')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=lcs,x='dpi',y='sr',hue='pop15', palette='viridis',size='pop75',sizes=(20,200))
plt.title('Savingratios,Income And Age Struture ' )
plt.xlabel('dpi')
plt.ylabel('sr')
plt.tight_layout()
plt.show()

# %%
lcs.index
# Out:
# Index(['Australia', 'Austria', 'Belgium', 'Bolivia', 'Brazil', 'Canada',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Denmark', 'Ecuador',
#        'Finland', 'France', 'Germany', 'Greece', 'Guatamala', 'Honduras',
#        'Iceland', 'India', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Malta', 'Norway', 'Netherlands', 'New Zealand', 'Nicaragua', 'Panama',
#        'Paraguay', 'Peru', 'Philippines', 'Portugal', 'South Africa',
#        'South Rhodesia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'Tunisia',
#        'United Kingdom', 'United States', 'Venezuela', 'Zambia', 'Jamaica',
#        'Uruguay', 'Libya', 'Malaysia'],
#       dtype='object')

# %%
lcs[lcs.index.str.contains('Korea')]
# Out:
#          sr  pop15  pop75     dpi  ddpi
# Korea  3.98  41.74   0.91  207.68  5.81

# %%
import matplotlib.pyplot as plt
point = [99,65,79,80,90]
name = ["영희", "철수", "윤철", "미현", "현수"]
plt.bar(name,point,color=["blue","purple","grey","orange","chartreuse"])
plt.title('데이터분석 점수');

# %%
import matplotlib.pyplot as plt
point = [99, 65, 79, 80, 90]
name = ["영희", "철수", "윤철", "미현", "현수"]
plt.barh(name, point, height = .6,
color = ["blue", "chartreuse", "purple", "grey", "orange"])
plt.title('데이터분석 점수')
plt.xlabel('이름')
plt.ylabel('점수');

# %%
from pydataset import data
mtc = data('mtcars')
mtc.mpg.quantile([0.,.25,.50,.75,1])
# Out:
# 0.00    10.400
# 0.25    15.425
# 0.50    19.200
# 0.75    22.800
# 1.00    33.900
# Name: mpg, dtype: float64

# %%
mtc.mpg.describe()[3:]
# Out:
# min    10.400
# 25%    15.425
# 50%    19.200
# 75%    22.800
# max    33.900
# Name: mpg, dtype: float64

# %%
plt.hist(mtc.mpg,edgecolor='yellow')
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.wt,edgecolor='white')
# Out:
# (array([3., 3., 3., 3., 9., 7., 1., 0., 0., 3.]),
#  array([1.513 , 1.9041, 2.2952, 2.6863, 3.0774, 3.4685, 3.8596, 4.2507,
#         4.6418, 5.0329, 5.424 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.wt,bins=5,edgecolor='black')
# Out:
# (array([ 6.,  6., 16.,  1.,  3.]),
#  array([1.513 , 2.2952, 3.0774, 3.8596, 4.6418, 5.424 ]),
#  <BarContainer object of 5 artists>)
